# %% [markdown]
# # What is Google Colab:
#
# - Google Colab is a free cloud service  for promoting the  Machine Learning to the education and Research. The Colab supports GPU and TPU and is totally free.
#
# - The Colab provide a service that allows user to access the Jupyter Notebook within a browser through moderate Internet Connections. Then, we will proceed further to build and test the machine learning projects.
# improve your Python programming language coding skills.
#
# - We can also develop the deep learning applications using popular libraries such as Keras, TensorFlow, PyTorch, and OpenCV.

# %% [markdown]
# #### For further Reference:
#
# https://colab.research.google.com/notebooks/welcome.ipynb
#
# https://research.google.com/colaboratory/faq.html?source=post_page---------------------------
